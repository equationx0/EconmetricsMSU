# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import linear_reset
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
D = pd.read_csv("Cottage.csv")

# Описательные статистики
print("Описательные статистики:")
print(D.describe())

# Матрица корреляций
print("\nМатрица корреляций:")
print(D.corr())

# Модель 1
model_1 = smf.ols('price ~ living_area + total_area + land + dist', data=D).fit()
print("\nМодель 1:")
print(model_1.summary())

# Проверка мультиколлинеарности (VIF)
X = D[['living_area', 'land', 'dist']]
X = sm.add_constant(X)
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print("\nVIF для модели 0:")
print(vif)

# Модель 2
model_2 = smf.ols('price ~ total_area + land + dist', data=D).fit()
print("\nМодель 2:")
print(model_2.summary())

# Модель 3
model_3 = smf.ols('np.log(price) ~ np.log(total_area) + np.log(land) + np.log(dist)', data=D).fit()
print("\nМодель 3:")
print(model_3.summary())

# Модель 4
model_4 = smf.ols('np.log(price) ~ np.log(total_area) + np.log(land) + np.log(dist) + lake', data=D).fit()
print("\nМодель 4:")
print(model_4.summary())

# Модель 5 (с взаимодействием)
model_5 = smf.ols('np.log(price) ~ np.log(total_area) + np.log(land) + np.log(dist) + lake:np.log(total_area)', data=D).fit()
print("\nМодель 5:")
print(model_5.summary())

# Сводная таблица моделей
from statsmodels.iolib.summary2 import summary_col
print("\nСводная таблица моделей:")
print(summary_col([model_1, model_2, model_3, model_4, model_5]))

# Тест Рамсея для модели 5
reset_result = linear_reset(model_5, power=3, test_type='fitted')
print("\nТест Рамсея для модели 5:")
print(reset_result.summary())
# Out:
# Описательные статистики:
#        living_area  total_area        land        dist        lake       price
# count   200.000000   200.00000  200.000000  200.000000  200.000000  200.000000
# mean     89.750000   113.24000   24.600000   60.910000    0.055000   16.570000
# std      28.656824    29.73522    8.963354   27.885118    0.228552   14.173551
# min      41.000000    54.00000   10.000000   10.000000    0.000000    2.000000
# 25%      65.500000    88.00000   17.000000   39.000000    0.000000    7.000000
# 50%      92.000000   114.50000   24.000000   58.500000    0.000000   13.000000
# 75%     113.000000   136.00000   32.000000   86.250000    0.000000   21.250000
# max     140.000000   175.00000   40.000000  109.000000    1.000000   99.000000
#
# Матрица корреляций:
#              living_area  total_area      land      dist      lake     price
# living_area     1.000000    0.962987 -0.068922 -0.192299 -0.005563  0.379072
# total_area      0.962987    1.000000 -0.083369 -0.186556 -0.018219  0.379730
# land           -0.068922   -0.083369  1.000000 -0.061123  0.003434  0.075652
# dist           -0.192299   -0.186556 -0.061123  1.000000  0.090667 -0.292708
# lake           -0.005563   -0.018219  0.003434  0.090667  1.000000  0.471162
# price           0.379072    0.379730  0.075652 -0.292708  0.471162  1.000000
#
# Модель 1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     12.54
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):           4.25e-09
# Time:                        01:28:23   Log-Likelihood:                -790.67
# No. Observations:                 200   AIC:                             1591.
# Df Residuals:                     195   BIC:                             1608.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.2597      5.658      0.399      0.690      -8.900      13.419
# living_area     0.0653      0.117      0.556      0.579      -0.166       0.297
# total_area      0.1043      0.113      0.922      0.358      -0.119       0.328
# land            0.1415      0.102      1.391      0.166      -0.059       0.342
# dist           -0.1123      0.033     -3.386      0.001      -0.178      -0.047
# ==============================================================================
# Omnibus:                      165.169   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2279.712
# Skew:                           3.124   Prob(JB):                         0.00
# Kurtosis:                      18.314   Cond. No.                     1.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# VIF для модели 0:
#       Variable        VIF
# 0        const  29.204208
# 1  living_area   1.045491
# 2         land   1.010606
# 3         dist   1.044427
#
# Модель 2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     16.68
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):           1.09e-09
# Time:                        01:28:23   Log-Likelihood:                -790.83
# No. Observations:                 200   AIC:                             1590.
# Df Residuals:                     196   BIC:                             1603.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2648      5.358      0.236      0.814      -9.302      11.832
# total_area     0.1648      0.031      5.303      0.000       0.104       0.226
# land           0.1437      0.101      1.416      0.158      -0.056       0.344
# dist          -0.1132      0.033     -3.420      0.001      -0.178      -0.048
# ==============================================================================
# Omnibus:                      165.388   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2299.027
# Skew:                           3.127   Prob(JB):                         0.00
# Kurtosis:                      18.388   Cond. No.                         794.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Модель 3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     30.10
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):           4.74e-16
# Time:                        01:28:23   Log-Likelihood:                -181.86
# No. Observations:                 200   AIC:                             371.7
# Df Residuals:                     196   BIC:                             384.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -1.6630      0.945     -1.759      0.080      -3.527       0.201
# np.log(total_area)     1.0424      0.157      6.632      0.000       0.732       1.352
# np.log(land)           0.2660      0.109      2.440      0.016       0.051       0.481
# np.log(dist)          -0.3831      0.075     -5.106      0.000      -0.531      -0.235
# ==============================================================================
# Omnibus:                        3.827   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.148   Jarque-Bera (JB):                3.856
# Skew:                           0.309   Prob(JB):                        0.145
# Kurtosis:                       2.715   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Модель 4:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     37.16
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):           4.39e-23
# Time:                        01:28:23   Log-Likelihood:                -163.09
# No. Observations:                 200   AIC:                             336.2
# Df Residuals:                     195   BIC:                             352.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -1.5485      0.863     -1.794      0.074      -3.251       0.154
# np.log(total_area)     1.0380      0.143      7.235      0.000       0.755       1.321
# np.log(land)           0.2602      0.100      2.615      0.010       0.064       0.456
# np.log(dist)          -0.4173      0.069     -6.075      0.000      -0.553      -0.282
# lake                   1.0934      0.172      6.345      0.000       0.754       1.433
# ==============================================================================
# Omnibus:                       23.296   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.002
# Skew:                          -0.009   Prob(JB):                       0.0302
# Kurtosis:                       2.084   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Модель 5:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     37.12
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):           4.59e-23
# Time:                        01:28:23   Log-Likelihood:                -163.13
# No. Observations:                 200   AIC:                             336.3
# Df Residuals:                     195   BIC:                             352.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.4914      0.863     -1.727      0.086      -3.194       0.212
# np.log(total_area)          1.0279      0.144      7.161      0.000       0.745       1.311
# np.log(land)                0.2579      0.100      2.591      0.010       0.062       0.454
# np.log(dist)               -0.4179      0.069     -6.081      0.000      -0.553      -0.282
# lake:np.log(total_area)     0.2330      0.037      6.336      0.000       0.160       0.305
# ==============================================================================
# Omnibus:                       23.830   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.085
# Skew:                          -0.017   Prob(JB):                       0.0289
# Kurtosis:                       2.079   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Сводная таблица моделей:
#
# ============================================================================================
#                         price I  price II np.log(price) I np.log(price) II np.log(price) III
# --------------------------------------------------------------------------------------------
# Intercept               2.2597   1.2648   -1.6630         -1.5485          -1.4914
#                         (5.6582) (5.3581) (0.9453)        (0.8630)         (0.8635)
# living_area             0.0653
#                         (0.1174)
# total_area              0.1043   0.1648
#                         (0.1132) (0.0311)
# land                    0.1415   0.1437
#                         (0.1017) (0.1015)
# dist                    -0.1123  -0.1132
#                         (0.0332) (0.0331)
# np.log(total_area)                        1.0424          1.0380           1.0279
#                                           (0.1572)        (0.1435)         (0.1435)
# np.log(land)                              0.2660          0.2602           0.2579
#                                           (0.1090)        (0.0995)         (0.0995)
# np.log(dist)                              -0.3831         -0.4173          -0.4179
#                                           (0.0750)        (0.0687)         (0.0687)
# lake                                                      1.0934
#                                                           (0.1723)
# lake:np.log(total_area)                                                    0.2330
#                                                                            (0.0368)
# R-squared               0.2046   0.2033   0.3154          0.4326           0.4323
# R-squared Adj.          0.1883   0.1912   0.3049          0.4209           0.4207
# ============================================================================================
# Standard errors in parentheses.
#
# Тест Рамсея для модели 5:
# <Wald test (chi2): statistic=1.13552908827715, p-value=0.5667910599494301, df_denom=2>
